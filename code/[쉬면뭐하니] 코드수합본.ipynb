# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## 1. 여가 비용 및 여가 시간 차이 분석

# %%
# 1. 여가관련 지출 및 동향
df1 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220502.csv")
df2 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220509.csv")
#df3 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220516.json")
df4 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220523.csv")
df5 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220530.csv")
df6 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220606.csv")
df7 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220613.csv")
df8 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220620.csv")
df9 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220627.csv")

# %%
import json
with open('/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/CI_LSR_CT_TNDCY_ND_INTEN_INFO_20220516.json') as f:
    js = json.loads(f.read())
df3 = pd.DataFrame(js)

# %%
df1.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df2.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df3.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df4.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df5.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df6.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df7.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df8.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']
df9.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '여가지출동향값', '여가지출의향값']

# %%
spend = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9], axis = 0).reset_index(drop=True)

# %%
def f1(spend):
    if (spend['여가지출동향값'] =='크게 증가했다'):
        val = 5
    elif (spend['여가지출동향값'] =='증가한 편이다'):
        val = 4
    elif (spend['여가지출동향값'] =='비슷하다'):
        val = 3
    elif (spend['여가지출동향값'] =='감소한 편이다'):
        val = 2
    else:
        val = 1
    return val

# %%
def f2(spend):
    if (spend['여가지출의향값'] =='크게 증가할 것이다'):
        val = 5
    elif (spend['여가지출의향값'] =='증가할 것이다'):
        val = 4
    elif (spend['여가지출의향값'] =='비슷할 것이다'):
        val = 3
    elif (spend['여가지출의향값'] =='감소할 것이다'):
        val = 2
    else:
        val = 1
    return val

# %%
spend['지출여가비용'] = spend.apply(f1, axis=1)
spend['희망여가비용'] = spend.apply(f2, axis=1)

# %%
y_spend1 = spend[(spend['연령대'] == '30대') | (spend['연령대'] == '40대')]
z_spend1 = spend[(spend['연령대'] == '20대')]

# %%
# 1. 여가관련 지출 및 동향
df1 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220502).csv")
df2 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220509).csv")
df3 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220516).csv")
df4 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220523).csv")
df5 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220530).csv")
df6 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220606).csv")
df7 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220613).csv")
df8 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220620).csv")
df9 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/10. 하루 평균 여가문화 시간 및 사용 비중(20220627).csv")

# %%
time = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9], axis = 0).reset_index(drop=True)

# %%
time.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '평일일평균레저시간값', '주말일평균레저시간값','1주총레저시간값','레저시간휴식오락사용비율', '레저시간취미사용비율', '레저시간본인계발사용비율', '레저시간대인관계교제사용비율', '레저시간기타사용비율']

# %%
y_spend2 = time[(time['연령대'] == '30대') | (time['연령대'] == '40대')]
z_spend2 = time[(time['연령대'] == '20대')]
y_spend2 = y_spend2[['ID','평일일평균레저시간값','주말일평균레저시간값','1주총레저시간값']]
z_spend2 = z_spend2[['ID','평일일평균레저시간값','주말일평균레저시간값','1주총레저시간값']]

# %%
yyy1 = pd.merge(y_spend1, y_spend2, how='inner',on='ID')
zzz1 = pd.merge(z_spend1, z_spend2, how='inner',on='ID')

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(yyy1['지출여가비용']),2))
print(round(np.mean(zzz1['지출여가비용']),2))
print(round(np.std(yyy1['지출여가비용']),2))
print(round(np.std(zzz1['지출여가비용']),2))
print(bartlett(yyy1['지출여가비용'], zzz1['지출여가비용'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(yyy1['지출여가비용'], zzz1['지출여가비용'], equal_var=False)) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 3.38
# 3.41
# 0.84
# 0.9
# BartlettResult(statistic=4.854150220829373, pvalue=0.02757969634017487)
# Ttest_indResult(statistic=-0.7838577456449186, pvalue=0.4332622691507757)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(yyy1['희망여가비용']),2))
print(round(np.mean(zzz1['희망여가비용']),2))
print(round(np.std(yyy1['희망여가비용']),2))
print(round(np.std(zzz1['희망여가비용']),2))
print(bartlett(yyy1['희망여가비용'], zzz1['희망여가비용'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(yyy1['희망여가비용'], zzz1['희망여가비용'])) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 3.51
# 3.44
# 0.75
# 0.76
# BartlettResult(statistic=0.22256475248898286, pvalue=0.6370926160706125)
# Ttest_indResult(statistic=2.163608734423585, pvalue=0.030593690365069127)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(yyy1['평일일평균레저시간값']),2))
print(round(np.mean(zzz1['평일일평균레저시간값']),2))
print(round(np.std(yyy1['평일일평균레저시간값']),2))
print(round(np.std(zzz1['평일일평균레저시간값']),2))
print(bartlett(yyy1['평일일평균레저시간값'], zzz1['평일일평균레저시간값'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(yyy1['평일일평균레저시간값'], zzz1['평일일평균레저시간값'], equal_var=False)) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 2.64
# 3.57
# 1.92
# 2.36
# BartlettResult(statistic=45.33842823648319, pvalue=1.6576451946954765e-11)
# Ttest_indResult(statistic=-9.363587913841824, pvalue=3.6967823290016434e-20)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(yyy1['주말일평균레저시간값']),2))
print(round(np.mean(zzz1['주말일평균레저시간값']),2))
print(round(np.std(yyy1['주말일평균레저시간값']),2))
print(round(np.std(zzz1['주말일평균레저시간값']),2))
print(bartlett(yyy1['주말일평균레저시간값'], zzz1['주말일평균레저시간값'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(yyy1['주말일평균레저시간값'], zzz1['주말일평균레저시간값'])) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 5.7
# 6.99
# 3.55
# 3.5
# BartlettResult(statistic=0.19362962263954187, pvalue=0.6599127279999792)
# Ttest_indResult(statistic=-8.245990212337325, pvalue=2.6763816424405617e-16)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(yyy1['1주총레저시간값']),2))
print(round(np.mean(zzz1['1주총레저시간값']),2))
print(round(np.std(yyy1['1주총레저시간값']),2))
print(round(np.std(zzz1['1주총레저시간값']),2))
print(bartlett(yyy1['1주총레저시간값'], zzz1['1주총레저시간값'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(yyy1['1주총레저시간값'], zzz1['1주총레저시간값'], equal_var=False)) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 24.61
# 31.82
# 14.17
# 15.92
# BartlettResult(statistic=14.429853332930445, pvalue=0.00014547775565298355)
# Ttest_indResult(statistic=-10.565004874846146, pvalue=4.474382680909449e-25)

# %%
yyy1['세대'] = 'Y세대'
zzz1['세대'] = 'Z세대'

# %%
total1 = pd.concat([yyy1,zzz1], axis =0).reset_index(drop=True)

# %% [markdown]
# ## 2.여가시간 활용 목적

# %%
# 2. 활용목적
df1 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220502).csv")
df2 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220509).csv")
df3 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220516).csv")
df4 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220523).csv")
df5 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220530).csv")
df6 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220606).csv")
df7 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220613).csv")
df8 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220620).csv")
df9 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/7. 여가시간 활용 목적(20220627).csv")

# %%
df1.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df2.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df3.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df4.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df5.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df6.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df7.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df8.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']
df9.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '1순위', '2순위']

# %%
purpose = pd.concat([df1, df2,df3,df4,df5,df6,df7,df8,df9], axis = 0).reset_index(drop=True)

# %%
y_purpose = purpose[(purpose['연령대'] == '30대') | (purpose['연령대'] == '40대')]
z_purpose = purpose[(purpose['연령대'] == '20대')]

# %%
round(y_purpose['1순위'].value_counts() 
/ len(y_purpose) *100, 2)
# Out:
# 가족-지인 등과 시간을 보내기 위해    26.89
# 자기만족-즐거움을 위해           18.41
# 마음의 안정-휴식을 위해          17.76
# 스트레스 해소를 위해            14.72
# 건강 관리를 위해               9.40
# 자기 계발을 위해               5.11
# 대인 관계-교제를 위해            4.40
# 남는 시간을 보내기 위해           2.99
# 기타                      0.33
# Name: 1순위, dtype: float64

# %%
round(z_purpose['1순위'].value_counts() 
/ len(z_purpose) *100, 2)
# Out:
# 자기만족-즐거움을 위해           29.04
# 마음의 안정-휴식을 위해          18.55
# 스트레스 해소를 위해            18.19
# 가족-지인 등과 시간을 보내기 위해    11.08
# 대인 관계-교제를 위해            7.35
# 자기 계발을 위해               6.75
# 건강 관리를 위해               4.58
# 남는 시간을 보내기 위해           4.46
# Name: 1순위, dtype: float64

# %% [markdown]
# ## 3.여가 사용 비중

# %%
y_spend2 = time[(time['연령대'] == '30대') | (time['연령대'] == '40대')]
z_spend2 = time[(time['연령대'] == '20대')]

# %%
y_use = y_spend2[['ID', '조사년월', '성별', '연령대', '거주지', '가구소득', '레저시간휴식오락사용비율', '레저시간취미사용비율', '레저시간본인계발사용비율',
       '레저시간대인관계교제사용비율', '레저시간기타사용비율']]
z_use = z_spend2[['ID', '조사년월', '성별', '연령대', '거주지', '가구소득', '레저시간휴식오락사용비율', '레저시간취미사용비율', '레저시간본인계발사용비율',
       '레저시간대인관계교제사용비율', '레저시간기타사용비율']]

# %%
y_use.reset_index(drop=True).head()
# Out:
#          ID      조사년월 성별  연령대    거주지           가구소득  레저시간휴식오락사용비율  레저시간취미사용비율  \
# 0  53322293  20220502  F  40대  서울특별시  300이상500만원 미만            50          30
# 1  53323594  20220502  M  30대  서울특별시       300만원 미만            50          10
# 2  53324165  20220502  F  40대  서울특별시  500이상700만원 미만            90           5
# 3  53325616  20220502  F  30대   충청북도  500이상700만원 미만            80           5
# 4  53325654  20220502  F  30대   전라북도  300이상500만원 미만            50           0
#
#    레저시간본인계발사용비율  레저시간대인관계교제사용비율  레저시간기타사용비율
# 0            10              10           0
# 1            10              30           0
# 2             1               4           0
# 3             5              10           0
# 4            30              20           0

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(y_use['레저시간휴식오락사용비율']),2))
print(round(np.mean(z_use['레저시간휴식오락사용비율']),2))
print(round(np.std(y_use['레저시간휴식오락사용비율']),2))
print(round(np.std(z_use['레저시간휴식오락사용비율']),2))
print(bartlett(y_use['레저시간휴식오락사용비율'], z_use['레저시간휴식오락사용비율'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(y_use['레저시간휴식오락사용비율'], z_use['레저시간휴식오락사용비율'])) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 42.53
# 46.66
# 25.84
# 25.85
# BartlettResult(statistic=0.00022891277916847592, pvalue=0.9879285758044135)
# Ttest_indResult(statistic=-3.821100183600538, pvalue=0.0001358895587679319)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(y_use['레저시간취미사용비율']),2))
print(round(np.mean(z_use['레저시간취미사용비율']),2))
print(round(np.std(y_use['레저시간취미사용비율']),2))
print(round(np.std(z_use['레저시간취미사용비율']),2))
print(bartlett(y_use['레저시간취미사용비율'], z_use['레저시간취미사용비율'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(y_use['레저시간취미사용비율'], z_use['레저시간취미사용비율'])) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 18.6
# 17.44
# 18.95
# 18.36
# BartlettResult(statistic=1.096725032342575, pvalue=0.29498594782103055)
# Ttest_indResult(statistic=1.46906537419773, pvalue=0.1419329095237882)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(y_use['레저시간본인계발사용비율']),2))
print(round(np.mean(z_use['레저시간본인계발사용비율']),2))
print(round(np.std(y_use['레저시간본인계발사용비율']),2))
print(round(np.std(z_use['레저시간본인계발사용비율']),2))
print(bartlett(y_use['레저시간본인계발사용비율'], z_use['레저시간본인계발사용비율'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(y_use['레저시간본인계발사용비율'], z_use['레저시간본인계발사용비율'], equal_var=False)) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 12.74
# 9.93
# 15.58
# 12.65
# BartlettResult(statistic=46.515418843146286, pvalue=9.090036092611263e-12)
# Ttest_indResult(statistic=4.929900556739931, pvalue=8.926688615099808e-07)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(y_use['레저시간대인관계교제사용비율']),2))
print(round(np.mean(z_use['레저시간대인관계교제사용비율']),2))
print(round(np.std(y_use['레저시간대인관계교제사용비율']),2))
print(round(np.std(z_use['레저시간대인관계교제사용비율']),2))
print(bartlett(y_use['레저시간대인관계교제사용비율'], z_use['레저시간대인관계교제사용비율'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(y_use['레저시간대인관계교제사용비율'], z_use['레저시간대인관계교제사용비율'])) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 22.4
# 24.68
# 19.64
# 20.71
# BartlettResult(statistic=3.318537151594449, pvalue=0.06850275722199699)
# Ttest_indResult(statistic=-2.721885332866844, pvalue=0.0065332356392509595)

# %%
from scipy.stats import bartlett, ttest_ind
print(round(np.mean(y_use['레저시간기타사용비율']),2))
print(round(np.mean(z_use['레저시간기타사용비율']),2))
print(round(np.std(y_use['레저시간기타사용비율']),2))
print(round(np.std(z_use['레저시간기타사용비율']),2))
print(bartlett(y_use['레저시간기타사용비율'], z_use['레저시간기타사용비율'])) #p-value가 0.05보다 큼 => 등분산성 가정 / 0.05보다 작음 => 이분산성 가정
print(ttest_ind(y_use['레저시간기타사용비율'], z_use['레저시간기타사용비율'], equal_var=False)) #p-value가 0.05보다 큼 => x / 0.05보다 작음 => 통계적으로 유의한 차이 존재
# Out:
# 3.73
# 1.29
# 13.88
# 8.0
# BartlettResult(statistic=292.3257524544968, pvalue=1.5481133736867229e-65)
# Ttest_indResult(statistic=5.722153480310134, pvalue=1.176458076456078e-08)

# %%
y_use['세대'] = 'Y세대'
z_use['세대'] = 'Z세대'
total2 = pd.concat([y_use,z_use], axis =0).reset_index(drop=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## 응답자 분석

# %%
round(y_use['성별'].value_counts() 
/ len(y_use) *100, 2)
# Out:
# M    50.95
# F    49.05
# Name: 성별, dtype: float64

# %%
round(z_use['성별'].value_counts() 
/ len(z_use) *100, 2)
# Out:
# M    51.93
# F    48.07
# Name: 성별, dtype: float64

# %%
round(y_use['거주지'].value_counts() 
/ len(y_use) *100, 2)
# Out:
# 경기도        25.42
# 서울특별시      15.54
# 경상남도        6.95
# 부산광역시       6.90
# 인천광역시       6.19
# 경상북도        5.05
# 대구광역시       4.56
# 대전광역시       3.97
# 광주광역시       3.97
# 충청북도        3.91
# 충청남도        3.53
# 강원도         3.15
# 울산광역시       3.04
# 전라남도        2.82
# 전라북도        2.77
# 제주특별자치도     1.36
# 세종특별자치시     0.87
# Name: 거주지, dtype: float64

# %%
round(z_use['거주지'].value_counts() 
/ len(z_use) *100, 2)
# Out:
# 경기도        23.37
# 서울특별시      18.43
# 부산광역시       7.35
# 경상남도        6.51
# 인천광역시       5.42
# 경상북도        5.18
# 충청남도        4.82
# 전라남도        4.46
# 대구광역시       4.22
# 광주광역시       3.86
# 전라북도        3.86
# 충청북도        3.37
# 대전광역시       3.25
# 울산광역시       2.05
# 강원도         1.81
# 제주특별자치도     1.20
# 세종특별자치시     0.84
# Name: 거주지, dtype: float64

# %%
round(y_use['가구소득'].value_counts() 
/ len(y_use) *100, 2)
# Out:
# 300이상500만원 미만    35.20
# 500이상700만원 미만    21.29
# 300만원 미만         20.97
# 700만원 이상         18.58
# 무응답               3.97
# Name: 가구소득, dtype: float64

# %%
round(z_use['가구소득'].value_counts() 
/ len(z_use) *100, 2)
# Out:
# 300만원 미만         31.45
# 300이상500만원 미만    21.93
# 무응답              16.99
# 700만원 이상         16.87
# 500이상700만원 미만    12.77
# Name: 가구소득, dtype: float64

# %% [markdown]
# ## 4. 여가문화 유형별 관심도

# %%
inte0502 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220502).csv")
inte0509 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220509).csv")
inte0516 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220516).csv")
inte0523 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220523).csv")
inte0530 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220530).csv")
inte0606 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220606).csv")
inte0613 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220613).csv")
inte0620 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220620).csv")
inte0627 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/6. 여가문화 유형별 관심도(20220627).csv")

# %%
inte = pd.concat([inte0502, inte0509, inte0516,inte0523, inte0530, inte0606, inte0613, inte0620, inte0627], axis = 0).reset_index(drop=True)

# %%
inte.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '문화예술관람관심정도값', '문화예술활동관심정도값', '스포츠관람관심정도값', '스포츠활동관심정도값', '관광여행관심정도값', '오락휴식관심정도값', '본인계발관심정도값', '사회교류관심정도값']

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'문화예술관람관심정도값'] == '매우 작아졌다':
    inte.loc[i,'문화예술관람관심정도값'] = 1
    
  elif inte.loc[i,'문화예술관람관심정도값'] == '조금 작아졌다':
    inte.loc[i,'문화예술관람관심정도값'] = 2

  elif inte.loc[i,'문화예술관람관심정도값'] == '비슷하다':
    inte.loc[i,'문화예술관람관심정도값'] = 3

  elif inte.loc[i,'문화예술관람관심정도값'] == '조금 커졌다':
    inte.loc[i,'문화예술관람관심정도값'] = 4

  elif inte.loc[i,'문화예술관람관심정도값'] == '매우 커졌다':
    inte.loc[i,'문화예술관람관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'문화예술활동관심정도값'] == '매우 작아졌다':
    inte.loc[i,'문화예술활동관심정도값'] = 1
    
  elif inte.loc[i,'문화예술활동관심정도값'] == '조금 작아졌다':
    inte.loc[i,'문화예술활동관심정도값'] = 2

  elif inte.loc[i,'문화예술활동관심정도값'] == '비슷하다':
    inte.loc[i,'문화예술활동관심정도값'] = 3

  elif inte.loc[i,'문화예술활동관심정도값'] == '조금 커졌다':
    inte.loc[i,'문화예술활동관심정도값'] = 4

  elif inte.loc[i,'문화예술활동관심정도값'] == '매우 커졌다':
    inte.loc[i,'문화예술활동관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'스포츠관람관심정도값'] == '매우 작아졌다':
    inte.loc[i,'스포츠관람관심정도값'] = 1
    
  elif inte.loc[i,'스포츠관람관심정도값'] == '조금 작아졌다':
    inte.loc[i,'스포츠관람관심정도값'] = 2

  elif inte.loc[i,'스포츠관람관심정도값'] == '비슷하다':
    inte.loc[i,'스포츠관람관심정도값'] = 3

  elif inte.loc[i,'스포츠관람관심정도값'] == '조금 커졌다':
    inte.loc[i,'스포츠관람관심정도값'] = 4

  elif inte.loc[i,'스포츠관람관심정도값'] == '매우 커졌다':
    inte.loc[i,'스포츠관람관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'스포츠활동관심정도값'] == '매우 작아졌다':
    inte.loc[i,'스포츠활동관심정도값'] = 1
    
  elif inte.loc[i,'스포츠활동관심정도값'] == '조금 작아졌다':
    inte.loc[i,'스포츠활동관심정도값'] = 2

  elif inte.loc[i,'스포츠활동관심정도값'] == '비슷하다':
    inte.loc[i,'스포츠활동관심정도값'] = 3

  elif inte.loc[i,'스포츠활동관심정도값'] == '조금 커졌다':
    inte.loc[i,'스포츠활동관심정도값'] = 4

  elif inte.loc[i,'스포츠활동관심정도값'] == '매우 커졌다':
    inte.loc[i,'스포츠활동관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'관광여행관심정도값'] == '매우 작아졌다':
    inte.loc[i,'관광여행관심정도값'] = 1
    
  elif inte.loc[i,'관광여행관심정도값'] == '조금 작아졌다':
    inte.loc[i,'관광여행관심정도값'] = 2

  elif inte.loc[i,'관광여행관심정도값'] == '비슷하다':
    inte.loc[i,'관광여행관심정도값'] = 3

  elif inte.loc[i,'관광여행관심정도값'] == '조금 커졌다':
    inte.loc[i,'관광여행관심정도값'] = 4

  elif inte.loc[i,'관광여행관심정도값'] == '매우 커졌다':
    inte.loc[i,'관광여행관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'오락휴식관심정도값'] == '매우 작아졌다':
    inte.loc[i,'오락휴식관심정도값'] = 1
    
  elif inte.loc[i,'오락휴식관심정도값'] == '조금 작아졌다':
    inte.loc[i,'오락휴식관심정도값'] = 2

  elif inte.loc[i,'오락휴식관심정도값'] == '비슷하다':
    inte.loc[i,'오락휴식관심정도값'] = 3

  elif inte.loc[i,'오락휴식관심정도값'] == '조금 커졌다':
    inte.loc[i,'오락휴식관심정도값'] = 4

  elif inte.loc[i,'오락휴식관심정도값'] == '매우 커졌다':
    inte.loc[i,'오락휴식관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'본인계발관심정도값'] == '매우 작아졌다':
    inte.loc[i,'본인계발관심정도값'] = 1
    
  elif inte.loc[i,'본인계발관심정도값'] == '조금 작아졌다':
    inte.loc[i,'본인계발관심정도값'] = 2

  elif inte.loc[i,'본인계발관심정도값'] == '비슷하다':
    inte.loc[i,'본인계발관심정도값'] = 3

  elif inte.loc[i,'본인계발관심정도값'] == '조금 커졌다':
    inte.loc[i,'본인계발관심정도값'] = 4

  elif inte.loc[i,'본인계발관심정도값'] == '매우 커졌다':
    inte.loc[i,'본인계발관심정도값'] = 5

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'사회교류관심정도값'] == '매우 작아졌다':
    inte.loc[i,'사회교류관심정도값'] = 1
    
  elif inte.loc[i,'사회교류관심정도값'] == '조금 작아졌다':
    inte.loc[i,'사회교류관심정도값'] = 2

  elif inte.loc[i,'사회교류관심정도값'] == '비슷하다':
    inte.loc[i,'사회교류관심정도값'] = 3

  elif inte.loc[i,'사회교류관심정도값'] == '조금 커졌다':
    inte.loc[i,'사회교류관심정도값'] = 4

  elif inte.loc[i,'사회교류관심정도값'] == '매우 커졌다':
    inte.loc[i,'사회교류관심정도값'] = 5

# %%
inte = inte[(inte['연령대'] == '20대') | (inte['연령대'] == '30대') | (inte['연령대'] == '40대')]
inte = inte.reset_index(drop=True)

# %%
inte['세대']=0

# %%
for i in range(len(inte)):
  
  if inte.loc[i,'연령대'] == '30대':
    inte.loc[i,'세대'] = 'y'
    
  elif inte.loc[i,'연령대'] == '40대':
    inte.loc[i,'세대'] = 'y'

  elif inte.loc[i,'연령대'] == '20대':
    inte.loc[i,'세대'] = 'z'

# %%
inte['문화예술관람관심정도값'] = pd.to_numeric(inte['문화예술관람관심정도값'])
inte['문화예술활동관심정도값'] = pd.to_numeric(inte['문화예술활동관심정도값'])
inte['스포츠관람관심정도값'] = pd.to_numeric(inte['스포츠관람관심정도값'])
inte['스포츠활동관심정도값'] = pd.to_numeric(inte['스포츠활동관심정도값'])
inte['관광여행관심정도값'] = pd.to_numeric(inte['관광여행관심정도값'])
inte['오락휴식관심정도값'] = pd.to_numeric(inte['오락휴식관심정도값'])
inte['본인계발관심정도값'] = pd.to_numeric(inte['본인계발관심정도값'])
inte['사회교류관심정도값'] = pd.to_numeric(inte['사회교류관심정도값'])

# %%
y_inte = inte[(inte['연령대'] == '30대') | (inte['연령대'] == '40대')]
z_inte = inte[(inte['연령대'] == '20대')]

# %%
pd.options.display.float_format = '{:.5f}'.format
y_inte.describe()
# Out:
#                   ID           조사년월  문화예술관람관심정도값  문화예술활동관심정도값  스포츠관람관심정도값  \
# count     1841.00000     1841.00000   1841.00000   1841.00000  1841.00000
# mean  53348542.30527 20220561.46388      3.19826      3.02336     3.06898
# std      15068.25900       50.98433      0.99199      0.97412     1.00980
# min   53322216.00000 20220502.00000      1.00000      1.00000     1.00000
# 25%   53335886.00000 20220516.00000      3.00000      3.00000     3.00000
# 50%   53347659.00000 20220530.00000      3.00000      3.00000     3.00000
# 75%   53360465.00000 20220613.00000      4.00000      4.00000     4.00000
# max   53377517.00000 20220627.00000      5.00000      5.00000     5.00000
#
#        스포츠활동관심정도값  관광여행관심정도값  오락휴식관심정도값  본인계발관심정도값  사회교류관심정도값
# count  1841.00000 1841.00000 1841.00000 1841.00000 1841.00000
# mean      3.33026    3.65834    3.52091    3.34221    3.08800
# std       0.99761    1.07847    0.85193    0.89940    1.00210
# ...

# %%
z_inte.describe()
# Out:
#                   ID           조사년월  문화예술관람관심정도값  문화예술활동관심정도값  스포츠관람관심정도값  \
# count      830.00000      830.00000    830.00000    830.00000   830.00000
# mean  53349203.97952 20220561.66988      3.37831      3.06747     3.09157
# std      15222.56499       50.94361      0.98799      0.98126     1.03441
# min   53322175.00000 20220502.00000      1.00000      1.00000     1.00000
# 25%   53335743.75000 20220516.00000      3.00000      3.00000     3.00000
# 50%   53348196.00000 20220530.00000      3.00000      3.00000     3.00000
# 75%   53360992.25000 20220613.00000      4.00000      4.00000     4.00000
# max   53377435.00000 20220627.00000      5.00000      5.00000     5.00000
#
#        스포츠활동관심정도값  관광여행관심정도값  오락휴식관심정도값  본인계발관심정도값  사회교류관심정도값
# count   830.00000  830.00000  830.00000  830.00000  830.00000
# mean      3.38313    3.79518    3.71325    3.54819    3.00723
# std       1.01744    1.02748    0.86742    0.90407    0.97864
# ...

# %%
from scipy.stats import bartlett

print(bartlett(y_inte['문화예술관람관심정도값'], z_inte['문화예술관람관심정도값']))
print(bartlett(y_inte['문화예술활동관심정도값'], z_inte['문화예술활동관심정도값']))
print(bartlett(y_inte['스포츠관람관심정도값'], z_inte['스포츠관람관심정도값']))
print(bartlett(y_inte['스포츠활동관심정도값'], z_inte['스포츠활동관심정도값']))
print(bartlett(y_inte['관광여행관심정도값'], z_inte['관광여행관심정도값']))
print(bartlett(y_inte['오락휴식관심정도값'], z_inte['오락휴식관심정도값']))
print(bartlett(y_inte['본인계발관심정도값'], z_inte['본인계발관심정도값']))
print(bartlett(y_inte['사회교류관심정도값'], z_inte['사회교류관심정도값']))
# Out:
# BartlettResult(statistic=0.018600068176864947, pvalue=0.8915192497372129)
# BartlettResult(statistic=0.061052512546472135, pvalue=0.8048400691028635)
# BartlettResult(statistic=0.6666672628267676, pvalue=0.4142159695275488)
# BartlettResult(statistic=0.4448183873745383, pvalue=0.5048059465283836)
# BartlettResult(statistic=2.6471092185979677, pvalue=0.10373838890801715)
# BartlettResult(statistic=0.3726135951396471, pvalue=0.5415830702525306)
# BartlettResult(statistic=0.030653216868192994, pvalue=0.8610163009394672)
# BartlettResult(statistic=0.6376281833910242, pvalue=0.42457097352647044)

# %%
import scipy.stats

print(scipy.stats.ttest_ind(y_inte['문화예술관람관심정도값'], z_inte['문화예술관람관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['문화예술활동관심정도값'], z_inte['문화예술활동관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['스포츠관람관심정도값'], z_inte['스포츠관람관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['스포츠활동관심정도값'], z_inte['스포츠활동관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['관광여행관심정도값'], z_inte['관광여행관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['오락휴식관심정도값'], z_inte['오락휴식관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['본인계발관심정도값'], z_inte['본인계발관심정도값'], equal_var=True))
print(scipy.stats.ttest_ind(y_inte['사회교류관심정도값'], z_inte['사회교류관심정도값'], equal_var=True))
# Out:
# Ttest_indResult(statistic=-4.346724922576739, pvalue=1.43357085373105e-05)
# Ttest_indResult(statistic=-1.0806694000515216, pvalue=0.27994183667873385)
# Ttest_indResult(statistic=-0.5308276987088641, pvalue=0.595582349513171)
# Ttest_indResult(statistic=-1.2599312429007044, pvalue=0.20780432024238982)
# Ttest_indResult(statistic=-3.0793705693094253, pvalue=0.0020954987398072093)
# Ttest_indResult(statistic=-5.369510047648836, pvalue=8.574956852242295e-08)
# Ttest_indResult(statistic=-5.46910831775189, pvalue=4.942480987062858e-08)
# Ttest_indResult(statistic=1.9417529496290358, pvalue=0.052272115495240364)

# %%
pd.options.display.float_format = '{:.5f}'.format
y_inte.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# ID            53348542.30527
# 조사년월          20220561.46388
# 문화예술관람관심정도값          3.19826
# 문화예술활동관심정도값          3.02336
# 스포츠관람관심정도값           3.06898
# 스포츠활동관심정도값           3.33026
# 관광여행관심정도값            3.65834
# 오락휴식관심정도값            3.52091
# 본인계발관심정도값            3.34221
# 사회교류관심정도값            3.08800
# dtype: float64

# %%
z_inte.mean()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ID            53349203.97952
# 조사년월          20220561.66988
# 문화예술관람관심정도값          3.37831
# 문화예술활동관심정도값          3.06747
# 스포츠관람관심정도값           3.09157
# 스포츠활동관심정도값           3.38313
# 관광여행관심정도값            3.79518
# 오락휴식관심정도값            3.71325
# 본인계발관심정도값            3.54819
# 사회교류관심정도값            3.00723
# dtype: float64

# %% [markdown]
# ## 5. 여가 경험 (3개월)

# %%
exp05 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/1. 여가문화 유형별 경험 여부(대분류)(202205).csv")
exp06 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/1. 여가문화 유형별 경험 여부(대분류)(202206).csv")

# %%
exp = pd.concat([exp05, exp06], axis = 0).reset_index(drop=True)

# %%
exp.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '3개월이내경험레저문화값', '1년도이내경험레저문화값']

# %%
exp['문화예술관람경험_count'] = len(exp) * [0]
exp['문화예술직접하기경험_count'] = len(exp) * [0]
exp['스포츠관람경험_count'] = len(exp) * [0]
exp['스포츠직접하기경험_count'] = len(exp) * [0]
exp['관광여행경험_count'] = len(exp) * [0]
exp['자기계발경험_count'] = len(exp) * [0]
exp['사회교류경험_count'] = len(exp) * [0]
exp['오락휴식경험_count'] = len(exp) * [0]

# %%
for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('문화예술 관람하기').loc[i] == True:
        exp.loc[i, '문화예술관람경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('문화예술 직접하기').loc[i] == True:
        exp.loc[i, '문화예술직접하기경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('스포츠 관람하기').loc[i] == True:
        exp.loc[i, '스포츠관람경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('운동-스포츠 직접하기').loc[i] == True:
        exp.loc[i, '스포츠직접하기경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('관광-여행').loc[i] == True:
        exp.loc[i, '관광여행경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('자기계발-자기관리').loc[i] == True:
        exp.loc[i, '자기계발경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('사회교류').loc[i] == True:
        exp.loc[i, '사회교류경험_count'] =  1

for i in range(len(exp)):    
    if exp.loc[[i]]['3개월이내경험레저문화값'].str.contains('오락-휴식').loc[i] == True:
        exp.loc[i, '오락휴식경험_count'] =  1

# %%
y_exp = exp[(exp['연령대'] == '30대') | (exp['연령대'] == '40대')]
z_exp = exp[(exp['연령대'] == '20대')]

# %%
y_df = pd.DataFrame(columns=['종류','ratio'])

# %%
new_row = {'종류':'문화예술 관람하기', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('문화예술 관람하기')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'문화예술 직접하기', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('문화예술 직접하기')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'스포츠 관람하기', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('스포츠 관람하기')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'운동-스포츠 직접하기', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('운동-스포츠 직접하기')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'관광-여행', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('관광-여행')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'자기계발-자기관리', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('자기계발-자기관리')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'사회교류', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('사회교류')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

new_row = {'종류':'오락-휴식', 'ratio':len(y_exp[y_exp['3개월이내경험레저문화값'].str.contains('오락-휴식')])/6616}
y_df = y_df.append(new_row, ignore_index=True)

# %%
y_df.sort_values('ratio', ascending=False)
# Out:
#             종류   ratio
# 7        오락-휴식 0.22249
# 4        관광-여행 0.17367
# 3  운동-스포츠 직접하기 0.14163
# 5    자기계발-자기관리 0.13256
# 6         사회교류 0.12500
# 0    문화예술 관람하기 0.11805
# 2     스포츠 관람하기 0.06258
# 1    문화예술 직접하기 0.02403

# %%
z_df = pd.DataFrame(columns=['종류','ratio'])

# %%
new_row = {'종류':'문화예술 관람하기', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('문화예술 관람하기')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

new_row = {'종류':'문화예술 직접하기', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('문화예술 직접하기')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

new_row = {'종류':'스포츠 관람하기', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('스포츠 관람하기')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

new_row = {'종류':'운동-스포츠 직접하기', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('운동-스포츠 직접하기')])/3219}

new_row = {'종류':'관광-여행', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('관광-여행')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

new_row = {'종류':'자기계발-자기관리', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('자기계발-자기관리')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

new_row = {'종류':'사회교류', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('사회교류')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

new_row = {'종류':'오락-휴식', 'ratio':len(z_exp[z_exp['3개월이내경험레저문화값'].str.contains('오락-휴식')])/3219}
z_df = z_df.append(new_row, ignore_index=True)

# %%
z_df.sort_values('ratio', ascending=False)
# Out:
#           종류   ratio
# 6      오락-휴식 0.22057
# 4  자기계발-자기관리 0.14756
# 3      관광-여행 0.14135
# 0  문화예술 관람하기 0.12644
# 5       사회교류 0.12644
# 2   스포츠 관람하기 0.07021
# 1  문화예술 직접하기 0.03200

# %% [markdown]
# ## 6. 여가 만족도

# %%
#만족도 평가
sat5 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/5. 여가생활 여건 및 만족도평가(2205).csv")
sat6 = pd.read_csv("/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/5. 여가생활 여건 및 만족도평가(2206).csv")

# %%
sat = pd.concat([sat5, sat6], axis = 0).reset_index(drop=True)

# %%
sat.columns = ['ID','조사년월','성별','연령대','거주지','가구소득', '시간충분만족정도값', '인프라및시설만족정도값', '경제여유만족정도값', '정보충분만족정도값', '레저생활전반만족정도값']

# %%
for i in range(len(sat)):
  
  if sat.loc[i,'시간충분만족정도값'] == '전혀 그렇지 않다':
    sat.loc[i,'시간충분만족정도값'] = 1
    
  elif sat.loc[i,'시간충분만족정도값'] == '그렇지 않은 편이다':
    sat.loc[i,'시간충분만족정도값'] = 2

  elif sat.loc[i,'시간충분만족정도값'] == '보통이다':
    sat.loc[i,'시간충분만족정도값'] = 3

  elif sat.loc[i,'시간충분만족정도값'] == '그런 편이다':
    sat.loc[i,'시간충분만족정도값'] = 4

  elif sat.loc[i,'시간충분만족정도값'] == '매우 그렇다':
    sat.loc[i,'시간충분만족정도값'] = 5

# %%
for i in range(len(sat)):
  
  if sat.loc[i,'인프라및시설만족정도값'] == '전혀 그렇지 않다':
    sat.loc[i,'인프라및시설만족정도값'] = 1
    
  elif sat.loc[i,'인프라및시설만족정도값'] == '그렇지 않은 편이다':
    sat.loc[i,'인프라및시설만족정도값'] = 2

  elif sat.loc[i,'인프라및시설만족정도값'] == '보통이다':
    sat.loc[i,'인프라및시설만족정도값'] = 3

  elif sat.loc[i,'인프라및시설만족정도값'] == '그런 편이다':
    sat.loc[i,'인프라및시설만족정도값'] = 4

  elif sat.loc[i,'인프라및시설만족정도값'] == '매우 그렇다':
    sat.loc[i,'인프라및시설만족정도값'] = 5

# %%
for i in range(len(sat)):
  
  if sat.loc[i,'경제여유만족정도값'] == '전혀 그렇지 않다':
    sat.loc[i,'경제여유만족정도값'] = 1
    
  elif sat.loc[i,'경제여유만족정도값'] == '그렇지 않은 편이다':
    sat.loc[i,'경제여유만족정도값'] = 2

  elif sat.loc[i,'경제여유만족정도값'] == '보통이다':
    sat.loc[i,'경제여유만족정도값'] = 3

  elif sat.loc[i,'경제여유만족정도값'] == '그런 편이다':
    sat.loc[i,'경제여유만족정도값'] = 4

  elif sat.loc[i,'경제여유만족정도값'] == '매우 그렇다':
    sat.loc[i,'경제여유만족정도값'] = 5

# %%
for i in range(len(sat)):
  
  if sat.loc[i,'정보충분만족정도값'] == '전혀 그렇지 않다':
    sat.loc[i,'정보충분만족정도값'] = 1
    
  elif sat.loc[i,'정보충분만족정도값'] == '그렇지 않은 편이다':
    sat.loc[i,'정보충분만족정도값'] = 2

  elif sat.loc[i,'정보충분만족정도값'] == '보통이다':
    sat.loc[i,'정보충분만족정도값'] = 3

  elif sat.loc[i,'정보충분만족정도값'] == '그런 편이다':
    sat.loc[i,'정보충분만족정도값'] = 4

  elif sat.loc[i,'정보충분만족정도값'] == '매우 그렇다':
    sat.loc[i,'정보충분만족정도값'] = 5

# %%
for i in range(len(sat)):
  
  if sat.loc[i,'레저생활전반만족정도값'] == '매우 불만족한다':
    sat.loc[i,'레저생활전반만족정도값'] = 1
    
  elif sat.loc[i,'레저생활전반만족정도값'] == '불만족하는 편이다':
    sat.loc[i,'레저생활전반만족정도값'] = 2

  elif sat.loc[i,'레저생활전반만족정도값'] == '보통이다':
    sat.loc[i,'레저생활전반만족정도값'] = 3

  elif sat.loc[i,'레저생활전반만족정도값'] == '만족하는 편이다':
    sat.loc[i,'레저생활전반만족정도값'] = 4

  elif sat.loc[i,'레저생활전반만족정도값'] == '매우 만족한다':
    sat.loc[i,'레저생활전반만족정도값'] = 5

# %%
sat['시간충분만족정도값'] = pd.to_numeric(sat['시간충분만족정도값'])
sat['인프라및시설만족정도값'] = pd.to_numeric(sat['인프라및시설만족정도값'])
sat['경제여유만족정도값'] = pd.to_numeric(sat['경제여유만족정도값'])
sat['정보충분만족정도값'] = pd.to_numeric(sat['정보충분만족정도값'])
sat['레저생활전반만족정도값'] = pd.to_numeric(sat['레저생활전반만족정도값'])

# %%
y_sat = sat[(sat['연령대'] == '30대') | (sat['연령대'] == '40대')]
z_sat = sat[(sat['연령대'] == '20대')]

# %%
y_sat.reset_index(drop=True).head()
# Out:
#          ID    조사년월 성별  연령대  거주지           가구소득  시간충분만족정도값  인프라및시설만족정도값  \
# 0  53345415  202205  M  40대  강원도       700만원 이상          2            1
# 1  53359839  202205  F  40대  강원도  300이상500만원 미만          2            2
# 2  53365904  202205  F  30대  강원도  300이상500만원 미만          1            1
# 3  53330730  202205  F  40대  강원도       700만원 이상          3            4
# 4  53357378  202205  F  30대  강원도  300이상500만원 미만          3            3
#
#    경제여유만족정도값  정보충분만족정도값  레저생활전반만족정도값
# 0          3          2            3
# 1          2          4            3
# 2          1          2            2
# 3          4          5            4
# 4          3          3            3

# %%
pd.options.display.float_format = '{:.5f}'.format
y_sat.describe()
# Out:
#                   ID         조사년월  시간충분만족정도값  인프라및시설만족정도값  경제여유만족정도값  \
# count     1841.00000   1841.00000 1841.00000   1841.00000 1841.00000
# mean  53348542.30527 202205.56056    3.00380      3.23031    2.96415
# std      15068.25900      0.49645    0.92870      0.89938    0.88761
# min   53322216.00000 202205.00000    1.00000      1.00000    1.00000
# 25%   53335886.00000 202205.00000    2.00000      3.00000    2.00000
# 50%   53347659.00000 202206.00000    3.00000      3.00000    3.00000
# 75%   53360465.00000 202206.00000    4.00000      4.00000    4.00000
# max   53377517.00000 202206.00000    5.00000      5.00000    5.00000
#
#        정보충분만족정도값  레저생활전반만족정도값
# count 1841.00000   1841.00000
# mean     3.35253      3.30310
# std      0.79476      0.78188
# min      1.00000      1.00000
# 25%      3.00000      3.00000
# 50%      3.00000      3.00000
# 75%      4.00000      4.00000
# max      5.00000      5.00000

# %%
z_sat.describe()
# Out:
#                   ID         조사년월  시간충분만족정도값  인프라및시설만족정도값  경제여유만족정도값  \
# count      830.00000    830.00000  830.00000    830.00000  830.00000
# mean  53349203.97952 202205.56265    3.09157      3.24337    2.89036
# std      15222.56499      0.49636    1.05862      1.04243    0.97187
# min   53322175.00000 202205.00000    1.00000      1.00000    1.00000
# 25%   53335743.75000 202205.00000    2.00000      2.25000    2.00000
# 50%   53348196.00000 202206.00000    3.00000      3.00000    3.00000
# 75%   53360992.25000 202206.00000    4.00000      4.00000    4.00000
# max   53377435.00000 202206.00000    5.00000      5.00000    5.00000
#
#        정보충분만족정도값  레저생활전반만족정도값
# count  830.00000    830.00000
# mean     3.46506      3.42048
# std      0.84397      0.79523
# min      1.00000      1.00000
# 25%      3.00000      3.00000
# 50%      4.00000      3.00000
# 75%      4.00000      4.00000
# max      5.00000      5.00000

# %%
from scipy.stats import bartlett

print(bartlett(y_sat['시간충분만족정도값'], z_sat['시간충분만족정도값']))
print(bartlett(y_sat['인프라및시설만족정도값'], z_sat['인프라및시설만족정도값']))
print(bartlett(y_sat['경제여유만족정도값'], z_sat['경제여유만족정도값']))
print(bartlett(y_sat['정보충분만족정도값'], z_sat['정보충분만족정도값']))
print(bartlett(y_sat['레저생활전반만족정도값'], z_sat['레저생활전반만족정도값']))
# Out:
# BartlettResult(statistic=20.199175298336446, pvalue=6.9783013770619765e-06)
# BartlettResult(statistic=25.76089477486086, pvalue=3.864394056156045e-07)
# BartlettResult(statistic=9.605718934327891, pvalue=0.0019397232025380982)
# BartlettResult(statistic=4.185649269611936, pvalue=0.04076759421164924)
# BartlettResult(statistic=0.328624705002581, pvalue=0.5664700359616235)

# %%
import scipy.stats

print(scipy.stats.ttest_ind(y_sat['시간충분만족정도값'], z_sat['시간충분만족정도값'], equal_var=False))
print(scipy.stats.ttest_ind(y_sat['인프라및시설만족정도값'], z_sat['인프라및시설만족정도값'], equal_var=False))
print(scipy.stats.ttest_ind(y_sat['경제여유만족정도값'], z_sat['경제여유만족정도값'], equal_var=False))
print(scipy.stats.ttest_ind(y_sat['정보충분만족정도값'], z_sat['정보충분만족정도값'], equal_var=False))
print(scipy.stats.ttest_ind(y_sat['레저생활전반만족정도값'], z_sat['레저생활전반만족정도값'], equal_var=True))
# Out:
# Ttest_indResult(statistic=-2.0579544043494646, pvalue=0.039775830924872836)
# Ttest_indResult(statistic=-0.3124116330509888, pvalue=0.7547739920591974)
# Ttest_indResult(statistic=1.8646640274641517, pvalue=0.06242689733748849)
# Ttest_indResult(statistic=-3.2468684905309995, pvalue=0.001192333268784099)
# Ttest_indResult(statistic=-3.5718409527328396, pvalue=0.00036074793298701617)

# %% [markdown]
# ## 합치기

# %%
yyy1.columns
# Out:
# Index(['ID', '조사년월', '성별', '연령대', '거주지', '가구소득', '여가지출동향값', '여가지출의향값',
#        '지출여가비용', '희망여가비용', '평일일평균레저시간값', '주말일평균레저시간값', '1주총레저시간값', '세대'],
#       dtype='object')

# %%
yyy_spend = yyy1[['ID', '조사년월', '성별', '연령대', '거주지', '가구소득','지출여가비용', '평일일평균레저시간값', '주말일평균레저시간값', '1주총레저시간값']]
zzz_spend = zzz1[['ID', '조사년월', '성별', '연령대', '거주지', '가구소득','지출여가비용', '평일일평균레저시간값', '주말일평균레저시간값', '1주총레저시간값']]
yyy_spend.columns = ['ID', '조사년월', '성별', '연령대', '거주지', '가구소득','지출여가비용', '일평균여가시간(평일)', '일평균여가시간(휴일)', '총여가시간']
zzz_spend.columns = ['ID', '조사년월', '성별', '연령대', '거주지', '가구소득','지출여가비용', '일평균여가시간(평일)', '일평균여가시간(휴일)', '총여가시간']

# %%
yyy_purpose = y_purpose[['ID', '1순위']]
yyy_purpose.columns = ['ID', '여가활동목적']
zzz_purpose = z_purpose[['ID', '1순위']]
zzz_purpose.columns = ['ID', '여가활동목적']

# %%
yyy_use = y_use[['ID', '레저시간휴식오락사용비율', '레저시간취미사용비율', '레저시간본인계발사용비율', '레저시간대인관계교제사용비율', '레저시간기타사용비율']]
yyy_use.columns = ['ID', '여가시간휴식오락사용비율', '여가시간취미사용비율', '여가시간본인계발사용비율', '여가시간대인관계교제사용비율', '여가시간기타사용비율']
zzz_use = z_use[['ID', '레저시간휴식오락사용비율', '레저시간취미사용비율', '레저시간본인계발사용비율', '레저시간대인관계교제사용비율', '레저시간기타사용비율']]
zzz_use.columns = ['ID', '여가시간휴식오락사용비율', '여가시간취미사용비율', '여가시간본인계발사용비율', '여가시간대인관계교제사용비율', '여가시간기타사용비율']

# %%
yyy_inte = y_inte[['ID', '문화예술관람관심정도값', '문화예술활동관심정도값','스포츠관람관심정도값', '스포츠활동관심정도값', '관광여행관심정도값', '오락휴식관심정도값', '본인계발관심정도값','사회교류관심정도값']]
zzz_inte = z_inte[['ID', '문화예술관람관심정도값', '문화예술활동관심정도값','스포츠관람관심정도값', '스포츠활동관심정도값', '관광여행관심정도값', '오락휴식관심정도값', '본인계발관심정도값','사회교류관심정도값']]

# %%
yyy_exp = y_exp[['ID','문화예술관람경험_count', '문화예술직접하기경험_count', '스포츠관람경험_count',
       '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count', '사회교류경험_count',
       '오락휴식경험_count']]

zzz_exp = z_exp[['ID','문화예술관람경험_count', '문화예술직접하기경험_count', '스포츠관람경험_count',
       '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count', '사회교류경험_count',
       '오락휴식경험_count']]

# %%
yyy_sat = y_sat[['ID', '시간충분만족정도값', '인프라및시설만족정도값',
       '경제여유만족정도값', '정보충분만족정도값', '레저생활전반만족정도값']]

zzz_sat = z_sat[['ID', '시간충분만족정도값', '인프라및시설만족정도값',
       '경제여유만족정도값', '정보충분만족정도값', '레저생활전반만족정도값']]

# %%
y_data = pd.merge(yyy_spend, yyy_purpose, how='inner',on='ID')
y_data = pd.merge(y_data, yyy_use, how='inner',on='ID')
y_data = pd.merge(y_data, yyy_inte, how='inner',on='ID')
y_data = pd.merge(y_data, yyy_exp, how='inner',on='ID')
y_data = pd.merge(y_data, yyy_sat, how='inner',on='ID')

y_data.to_csv('/content/drive/Shareddrives/문체부 경진대회/y세대_final.csv', index=False)

# %%
z_data = pd.merge(zzz_spend, zzz_purpose, how='inner',on='ID')
z_data = pd.merge(z_data, zzz_use, how='inner',on='ID')
z_data = pd.merge(z_data, zzz_inte, how='inner',on='ID')
z_data = pd.merge(z_data, zzz_exp, how='inner',on='ID')
z_data = pd.merge(z_data, zzz_sat, how='inner',on='ID')

# %% [markdown]
# ## 여가만족도 영향 요인

# %% [markdown]
# ### y세대

# %%
# 성별, 가구소득, 시간충분, 인프라, 경제여유, 정보충분
for i in range(len(y_data)):
  
  if y_data.loc[i,'성별'] == 'M':
    y_data.loc[i,'성별'] = 1
  elif y_data.loc[i,'성별'] == 'F':
    y_data.loc[i,'성별'] = 0

# %%
for i in range(len(y_data)):
  
  if y_data.loc[i,'가구소득'] == '300만원 미만':
    y_data.loc[i,'가구소득'] = 1
  elif y_data.loc[i,'가구소득'] == '300이상500만원 미만':
    y_data.loc[i,'가구소득'] = 2
  elif y_data.loc[i,'가구소득'] == '500이상700만원 미만':
    y_data.loc[i,'가구소득'] = 3
  elif y_data.loc[i,'가구소득'] == '700만원 이상':
    y_data.loc[i,'가구소득'] = 4
  elif y_data.loc[i,'가구소득'] == '무응답':
    y_data.loc[i,'가구소득'] = 2.5

# %%
y_data['성별'] = pd.to_numeric(y_data['성별'])
y_data['가구소득'] = pd.to_numeric(y_data['가구소득'])

# %%
yyy_data = y_data[['성별','가구소득',  '지출여가비용', '일평균여가시간(평일)',
       '일평균여가시간(휴일)', '총여가시간', '문화예술관람경험_count', '문화예술직접하기경험_count',
       '스포츠관람경험_count', '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count',
       '사회교류경험_count', '오락휴식경험_count', '시간충분만족정도값', '인프라및시설만족정도값', '경제여유만족정도값',
       '정보충분만족정도값','레저생활전반만족정도값']]

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
yyy_data = pd.DataFrame(scaler.fit_transform(yyy_data), columns=yyy_data.columns)

# %%
X = yyy_data[['성별','가구소득',  '지출여가비용', '일평균여가시간(평일)',
       '일평균여가시간(휴일)',  '문화예술관람경험_count', '문화예술직접하기경험_count',
       '스포츠관람경험_count', '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count',
       '사회교류경험_count', '오락휴식경험_count', '시간충분만족정도값', '인프라및시설만족정도값', '경제여유만족정도값',
       '정보충분만족정도값']]
y = yyy_data['레저생활전반만족정도값']

# %%
import statsmodels.api as sm

model = sm.OLS(y, X).fit()
predictions = model.predict (X)

model.summary ()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            레저생활전반만족정도값   R-squared (uncentered):                   0.934
# Model:                            OLS   Adj. R-squared (uncentered):              0.933
# Method:                 Least Squares   F-statistic:                              1345.
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):                        0.00
# Time:                        00:04:45   Log-Likelihood:                          717.17
# No. Observations:                1641   AIC:                                     -1400.
# Df Residuals:                    1624   BIC:                                     -1308.
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### z세대

# %%
# 성별, 가구소득, 시간충분, 인프라, 경제여유, 정보충분
for i in range(len(z_data)):
  
  if z_data.loc[i,'성별'] == 'M':
    z_data.loc[i,'성별'] = 1
  elif z_data.loc[i,'성별'] == 'F':
    z_data.loc[i,'성별'] = 0

# %%
for i in range(len(z_data)):
  
  if z_data.loc[i,'가구소득'] == '300만원 미만':
    z_data.loc[i,'가구소득'] = 1
  elif z_data.loc[i,'가구소득'] == '300이상500만원 미만':
    z_data.loc[i,'가구소득'] = 2
  elif z_data.loc[i,'가구소득'] == '500이상700만원 미만':
    z_data.loc[i,'가구소득'] = 3
  elif z_data.loc[i,'가구소득'] == '700만원 이상':
    z_data.loc[i,'가구소득'] = 4
  elif z_data.loc[i,'가구소득'] == '무응답':
    z_data.loc[i,'가구소득'] = 2.5

# %%
z_data['성별'] = pd.to_numeric(z_data['성별'])
z_data['가구소득'] = pd.to_numeric(z_data['가구소득'])

# %%
zzz_data = z_data[['성별','가구소득',  '지출여가비용', '일평균여가시간(평일)',
       '일평균여가시간(휴일)', '총여가시간', '문화예술관람경험_count', '문화예술직접하기경험_count',
       '스포츠관람경험_count', '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count',
       '사회교류경험_count', '오락휴식경험_count', '시간충분만족정도값', '인프라및시설만족정도값', '경제여유만족정도값',
       '정보충분만족정도값','레저생활전반만족정도값']]

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

scaler = MinMaxScaler()
zzz_data = pd.DataFrame(scaler.fit_transform(zzz_data), columns=zzz_data.columns)

# %%
zzz_data
# Out:
#          성별    가구소득  지출여가비용  일평균여가시간(평일)  일평균여가시간(휴일)   총여가시간  문화예술관람경험_count  \
# 0   1.00000 0.33333 0.50000      0.25000      0.25000 0.26087         0.00000
# 1   1.00000 0.50000 0.50000      0.06250      0.25000 0.09783         0.00000
# 2   1.00000 0.66667 0.75000      0.25000      0.50000 0.34783         0.00000
# 3   1.00000 0.33333 0.75000      0.37500      0.75000 0.54348         1.00000
# 4   1.00000 1.00000 0.75000      0.37500      0.37500 0.41304         0.00000
# ..      ...     ...     ...          ...          ...     ...             ...
# 734 1.00000 1.00000 0.50000      0.12500      0.31250 0.17391         0.00000
# 735 0.00000 0.00000 0.25000      0.75000      0.75000 0.86957         1.00000
# 736 0.00000 0.00000 0.50000      0.31250      0.62500 0.44565         0.00000
# 737 0.00000 0.66667 0.50000      0.31250      0.31250 0.33696         1.00000
# 738 0.00000 1.00000 0.50000      0.18750      0.31250 0.22826         1.00000
#
# ...

# %%
X = zzz_data[['성별','가구소득',  '지출여가비용', '일평균여가시간(평일)',
       '일평균여가시간(휴일)',  '문화예술관람경험_count', '문화예술직접하기경험_count',
       '스포츠관람경험_count', '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count',
       '사회교류경험_count', '오락휴식경험_count', '시간충분만족정도값', '인프라및시설만족정도값', '경제여유만족정도값',
       '정보충분만족정도값']]
y = zzz_data['레저생활전반만족정도값']

# %%
import statsmodels.api as sm

model = sm.OLS(y, X).fit()
predictions = model.predict (X)

model.summary ()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# ...
# Dep. Variable:            레저생활전반만족정도값   R-squared (uncentered):                   0.937
# Model:                            OLS   Adj. R-squared (uncentered):              0.935
# Method:                 Least Squares   F-statistic:                              631.1
# Date:                Sun, 04 Sep 2022   Prob (F-statistic):                        0.00
# Time:                        00:04:50   Log-Likelihood:                          308.92
# No. Observations:                 739   AIC:                                     -583.8
# Df Residuals:                     722   BIC:                                     -505.6
# Df Model:                          17
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...

# %%
df_y = pd.read_csv('/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/y세대 군집화 준비2.csv')
df_z = pd.read_csv('/content/drive/Shareddrives/문체부 경진대회/최종/코드수합본_데이터/z세대 군집화 준비2.csv')

# %% [markdown]
# 7개 지역으로 구분
# 서울특별시, 부산광역시, 대구광역시, 울산광역시, 광주광역시, 인천광역시, 대전광역시

# %%
region_lst = ['서울특별시','대구광역시', '인천광역시','광주광역시','부산광역시', '울산광역시','대전광역시']

# %%
df_y = df_y.loc[df_y['거주지'].isin(region_lst)]
df_z = df_z.loc[df_z['거주지'].isin(region_lst)]

# %% [markdown]
# 필요한 column만 추출

# %%
column_lst = ['거주지','평일일평균레저시간값',
       '주말일평균레저시간값', '1주총레저시간값', '문화예술관람경험_count', '문화예술직접하기경험_count',
       '스포츠관람경험_count', '스포츠직접하기경험_count', '관광여행경험_count', '자기계발경험_count',
       '사회교류경험_count', '오락휴식경험_count', '시간충분만족정도값', '인프라및시설만족정도값', '경제여유만족정도값',
       '정보충분만족정도값', '레저생활전반만족정도값']

# %%
df_y = df_y[column_lst]
df_z = df_z[column_lst]

# %%
df_y = df_y.groupby('거주지').agg('mean')
df_z = df_z.groupby('거주지').agg('mean')

# %% [markdown]
# # Agglomerative clustering_y세대

# %%
import scipy.cluster.hierarchy as shc
cluster = shc.linkage(df_y, method = 'average')

# %%
plt.figure(figsize=(20, 15))
plt.title("Dendogram_average")
dend = shc.dendrogram(cluster)
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

agg = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='average')
result = agg.fit_predict(df_y)

# %%
result = list(result)
agglomerative_3 = pd.DataFrame({'거주지' : df_y.index, '군집' : result})
agglomerative_3
# Out:
#      거주지  군집
# 0  광주광역시   0
# 1  대구광역시   0
# 2  대전광역시   1
# 3  부산광역시   0
# 4  서울특별시   2
# 5  울산광역시   0
# 6  인천광역시   2

# %%
agglomerative_3['군집'].value_counts()
# Out:
# 0    4
# 2    2
# 1    1
# Name: 군집, dtype: int64

# %%
c_0 = list(agglomerative_3[agglomerative_3['군집']==0]['거주지'])
c_0
# Out:
# ['광주광역시', '대구광역시', '부산광역시', '울산광역시']

# %%
c_1 = list(agglomerative_3[agglomerative_3['군집']==1]['거주지'])
c_1
# Out:
# ['대전광역시']

# %%
c_2 = list(agglomerative_3[agglomerative_3['군집']==2]['거주지'])
c_2
# Out:
# ['서울특별시', '인천광역시']

# %% [markdown]
# # Kmeans clustering_y세대

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,random_state=2022).fit(df_y)
labels=kmeans.labels_
centers=kmeans.cluster_centers_

# %%
df_y['clustering']=labels
result = list(labels)
kmeans_3 = pd.DataFrame({'거주지' : df_y.index, '군집' : result})
kmeans_3
# Out:
#      거주지  군집
# 0  광주광역시   1
# 1  대구광역시   1
# 2  대전광역시   2
# 3  부산광역시   0
# 4  서울특별시   0
# 5  울산광역시   1
# 6  인천광역시   0

# %%
kmeans_3['군집'].value_counts()
# Out:
# 1    3
# 0    3
# 2    1
# Name: 군집, dtype: int64

# %%
c_0 = list(kmeans_3[kmeans_3['군집']==0]['거주지'])
c_0
# Out:
# ['부산광역시', '서울특별시', '인천광역시']

# %%
c_1 = list(kmeans_3[kmeans_3['군집']==1]['거주지'])
c_1
# Out:
# ['광주광역시', '대구광역시', '울산광역시']

# %%
c_2 = list(kmeans_3[kmeans_3['군집']==2]['거주지'])
c_2
# Out:
# ['대전광역시']

# %% [markdown]
# 3,3,1로 묶기

# %% [markdown]
# # Agglomerative clustering_z세대

# %%
cluster = shc.linkage(df_z, method = 'average')

# %%
plt.figure(figsize=(20, 15))
plt.title("Dendogram_average")
dend = shc.dendrogram(cluster)
plt.show()

# %%
agg = AgglomerativeClustering(n_clusters=3, affinity='euclidean', linkage='average')
result = agg.fit_predict(df_z)

# %%
result = list(result)
agglomerative_3 = pd.DataFrame({'거주지' : df_z.index, '군집' : result})
agglomerative_3
# Out:
#      거주지  군집
# 0  광주광역시   0
# 1  대구광역시   1
# 2  대전광역시   0
# 3  부산광역시   1
# 4  서울특별시   0
# 5  울산광역시   2
# 6  인천광역시   0

# %%
c_0 = list(agglomerative_3[agglomerative_3['군집']==0]['거주지'])
c_0
# Out:
# ['광주광역시', '대전광역시', '서울특별시', '인천광역시']

# %%
c_1 = list(agglomerative_3[agglomerative_3['군집']==1]['거주지'])
c_1
# Out:
# ['대구광역시', '부산광역시']

# %%
c_2 = list(agglomerative_3[agglomerative_3['군집']==2]['거주지'])
c_2
# Out:
# ['울산광역시']

# %% [markdown]
# # Kmeans clustering_z세대

# %%
kmeans = KMeans(n_clusters=3,random_state=2022).fit(df_z)
labels=kmeans.labels_

# %%
df_z['clustering']=labels
result = list(labels)
kmeans_3 = pd.DataFrame({'거주지' : df_z.index, '군집' : result})
kmeans_3
# Out:
#      거주지  군집
# 0  광주광역시   2
# 1  대구광역시   1
# 2  대전광역시   2
# 3  부산광역시   1
# 4  서울특별시   2
# 5  울산광역시   0
# 6  인천광역시   0

# %%
kmeans_3['군집'].value_counts()
# Out:
# 2    3
# 1    2
# 0    2
# Name: 군집, dtype: int64

# %%
c_0 = list(kmeans_3[kmeans_3['군집']==0]['거주지'])
c_0
# Out:
# ['울산광역시', '인천광역시']

# %%
c_1 = list(kmeans_3[kmeans_3['군집']==1]['거주지'])
c_1
# Out:
# ['대구광역시', '부산광역시']

# %%
c_2 = list(kmeans_3[kmeans_3['군집']==2]['거주지'])
c_2
# Out:
# ['광주광역시', '대전광역시', '서울특별시']

# %% [markdown]
# 2,3,2로 묶기

# %% [markdown]
# # y세대 군집 기초통계

# %%
y_lst_1 = ['광주광역시', '대구광역시', '울산광역시']
y_lst_2 = ['부산광역시', '서울특별시', '인천광역시']
y_lst_3 = ['대전광역시']

# %%
y_cluster_1 = df_y.loc[df_y.index.isin(y_lst_1)]
y_cluster_2 = df_y.loc[df_y.index.isin(y_lst_2)]
y_cluster_3 = df_y.loc[df_y.index.isin(y_lst_3)]

# %%
y_columns = list(y_cluster_1.columns)
y_columns
# Out:
# ['평일일평균레저시간값',
#  '주말일평균레저시간값',
#  '1주총레저시간값',
#  '문화예술관람경험_count',
#  '문화예술직접하기경험_count',
#  '스포츠관람경험_count',
#  '스포츠직접하기경험_count',
#  '관광여행경험_count',
#  '자기계발경험_count',
#  '사회교류경험_count',
#  '오락휴식경험_count',
#  '시간충분만족정도값',
#  '인프라및시설만족정도값',
#  '경제여유만족정도값',
#  '정보충분만족정도값',
#  '레저생활전반만족정도값',
#  'clustering']

# %%
y_cluster_1_lst = list(y_cluster_1.mean())
y_cluster_2_lst = list(y_cluster_2.mean())
y_cluster_3_lst = list(y_cluster_3.mean())

# %%
y_cluster_1_lst
# Out:
# [2.55879884004884,
#  5.357140131693703,
#  23.508274463631608,
#  0.4327549930228501,
#  0.0632685766614338,
#  0.22628859236002094,
#  0.48163319815105526,
#  0.6027276295133438,
#  0.3616889063317635,
#  0.43413952119309257,
#  0.7774589002267573,
#  2.914279173207745,
#  3.1631944444444446,
#  2.8335649965114253,
#  3.2677890066282926,
#  3.2855344060701204,
#  1.0]

# %%
value_dict = { 'y_부산서울인천':y_cluster_2_lst, 'y_광주대구울산':y_cluster_1_lst,'y_대전':y_cluster_3_lst}
total_y = pd.DataFrame(value_dict, index = y_columns)
total_y
# Out:
#                   y_부산서울인천  y_광주대구울산     y_대전
# 평일일평균레저시간값         2.58091   2.55880  2.30769
# 주말일평균레저시간값         5.96017   5.35714  5.24615
# 1주총레저시간값          24.82486  23.50827 22.03077
# 문화예술관람경험_count     0.42007   0.43275  0.47692
# 문화예술직접하기경험_count   0.09211   0.06327  0.04615
# 스포츠관람경험_count      0.23520   0.22629  0.23077
# 스포츠직접하기경험_count    0.52325   0.48163  0.58462
# 관광여행경험_count       0.61326   0.60273  0.58462
# 자기계발경험_count       0.50632   0.36169  0.41538
# 사회교류경험_count       0.44841   0.43414  0.43077
# 오락휴식경험_count       0.82466   0.77746  0.76923
# 시간충분만족정도값          2.98551   2.91428  2.76923
# 인프라및시설만족정도값        3.39588   3.16319  3.10769
# 경제여유만족정도값          2.97771   2.83356  2.83077
# 정보충분만족정도값          3.43725   3.26779  3.24615
# 레저생활전반만족정도값        3.27829   3.28553  3.13846
# clustering         0.00000   1.00000  2.00000

# %%
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-460
# Use 'sudo apt autoremove' to remove it.
# The following NEW packages will be installed:
#   fonts-nanum
# 0 upgraded, 1 newly installed, 0 to remove and 20 not upgraded.
# Need to get 9,604 kB of archives.
# After this operation, 29.5 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu bionic/universe amd64 fonts-nanum all 20170925-1 [9,604 kB]
# Fetched 9,604 kB in 1s (9,465 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 76, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# ...

# %%
import matplotlib.pyplot as plt
import numpy as np

# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(3)

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(index, total_y[:3]['y_부산서울인천'], bar_width, alpha=0.4, color='red', label='class1')

b2 = plt.bar(index + bar_width, total_y[:3]['y_광주대구울산'], bar_width, alpha=0.4, color='blue', label='class2')

b3 = plt.bar(index + 2 * bar_width, total_y[:3]['y_대전'], bar_width, alpha=0.4, color='green', label='class3')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 3 + bar_width, 1), y_columns)
plt.rc('font', family='NanumBarunGothic') 

# x축, y축 이름 및 범례 설정
plt.xlabel('variable', size = 13)
plt.ylabel('value', size = 13)
plt.rc('font', family='NanumBarunGothic') 
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(8)

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(index, total_y[3:11]['y_부산서울인천'], bar_width, alpha=0.4, color='red', label='class1')

b2 = plt.bar(index + bar_width, total_y[3:11]['y_광주대구울산'], bar_width, alpha=0.4, color='blue', label='class2')

b3 = plt.bar(index + 2 * bar_width, total_y[3:11]['y_대전'], bar_width, alpha=0.4, color='green', label='class3')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 8 + bar_width, 1), y_columns[3:11])
plt.rc('font', family='NanumBarunGothic') 

# x축, y축 이름 및 범례 설정
plt.xlabel('variable', size = 13)
plt.ylabel('value', size = 13)
plt.rc('font', family='NanumBarunGothic') 
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(5)

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(index, total_y[11:16]['y_부산서울인천'], bar_width, alpha=0.4, color='red', label='class1')

b2 = plt.bar(index + bar_width, total_y[11:16]['y_광주대구울산'], bar_width, alpha=0.4, color='blue', label='class2')

b3 = plt.bar(index + 2 * bar_width, total_y[11:16]['y_대전'], bar_width, alpha=0.4, color='green', label='class3')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 5 + bar_width, 1), y_columns[11:16])
plt.rc('font', family='NanumBarunGothic') 

# x축, y축 이름 및 범례 설정
plt.xlabel('variable', size = 13)
plt.ylabel('value', size = 13)
plt.rc('font', family='NanumBarunGothic') 
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51313 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
value_dict = {'변수' : y_columns,  'y_부산서울인천':y_cluster_2_lst,'y_광주대구울산':y_cluster_1_lst, 'y_대전':y_cluster_3_lst}
total_y = pd.DataFrame(value_dict)
total_y
# Out:
#                   변수  y_부산서울인천  y_광주대구울산     y_대전
# 0         평일일평균레저시간값   2.58091   2.55880  2.30769
# 1         주말일평균레저시간값   5.96017   5.35714  5.24615
# 2           1주총레저시간값  24.82486  23.50827 22.03077
# 3     문화예술관람경험_count   0.42007   0.43275  0.47692
# 4   문화예술직접하기경험_count   0.09211   0.06327  0.04615
# 5      스포츠관람경험_count   0.23520   0.22629  0.23077
# 6    스포츠직접하기경험_count   0.52325   0.48163  0.58462
# 7       관광여행경험_count   0.61326   0.60273  0.58462
# 8       자기계발경험_count   0.50632   0.36169  0.41538
# 9       사회교류경험_count   0.44841   0.43414  0.43077
# 10      오락휴식경험_count   0.82466   0.77746  0.76923
# 11         시간충분만족정도값   2.98551   2.91428  2.76923
# 12       인프라및시설만족정도값   3.39588   3.16319  3.10769
# 13         경제여유만족정도값   2.97771   2.83356  2.83077
# 14         정보충분만족정도값   3.43725   3.26779  3.24615
# 15       레저생활전반만족정도값   3.27829   3.28553  3.13846
# 16        clustering   0.00000   1.00000  2.00000

# %% [markdown]
# # z세대 군집 기초통계

# %%
z_lst_1 = ['울산광역시', '인천광역시']
z_lst_2 = ['광주광역시', '대전광역시', '서울특별시']
z_lst_3 = ['대구광역시', '부산광역시']

# %%
z_cluster_1 = df_z.loc[df_z.index.isin(z_lst_1)]
z_cluster_2 = df_z.loc[df_z.index.isin(z_lst_2)]
z_cluster_3 = df_z.loc[df_z.index.isin(z_lst_3)]

# %%
z_cluster_1_lst = list(z_cluster_1.mean())
z_cluster_2_lst = list(z_cluster_2.mean())
z_cluster_3_lst = list(z_cluster_3.mean())

# %%
z_columns = list(z_cluster_1.columns)
z_columns
# Out:
# ['평일일평균레저시간값',
#  '주말일평균레저시간값',
#  '1주총레저시간값',
#  '문화예술관람경험_count',
#  '문화예술직접하기경험_count',
#  '스포츠관람경험_count',
#  '스포츠직접하기경험_count',
#  '관광여행경험_count',
#  '자기계발경험_count',
#  '사회교류경험_count',
#  '오락휴식경험_count',
#  '시간충분만족정도값',
#  '인프라및시설만족정도값',
#  '경제여유만족정도값',
#  '정보충분만족정도값',
#  '레저생활전반만족정도값',
#  'clustering']

# %%
value_dict = {'z_대구부산':z_cluster_3_lst,'z_광주대전서울':z_cluster_2_lst, 'z_울산인천':z_cluster_1_lst }
total_z = pd.DataFrame(value_dict, index = z_columns)
total_z
# Out:
#                    z_대구부산  z_광주대전서울   z_울산인천
# 평일일평균레저시간값        4.04926   3.53083  3.51842
# 주말일평균레저시간값        6.91872   6.86872  6.28684
# 1주총레저시간값         34.08374  31.39159 30.16579
# 문화예술관람경험_count    0.38793   0.43550  0.57018
# 문화예술직접하기경험_count  0.13085   0.10654  0.15263
# 스포츠관람경험_count     0.28202   0.26880  0.23860
# 스포츠직접하기경험_count   0.46521   0.48832  0.50351
# 관광여행경험_count      0.51755   0.54336  0.51667
# 자기계발경험_count      0.50985   0.48170  0.60965
# 사회교류경험_count      0.45628   0.40934  0.47719
# 오락휴식경험_count      0.82451   0.86662  0.78772
# 시간충분만족정도값         3.04649   2.98895  3.27632
# 인프라및시설만족정도값       3.37069   3.48135  3.22368
# 경제여유만족정도값         2.88701   2.70366  2.81404
# 정보충분만족정도값         3.44982   3.48392  3.70263
# 레저생활전반만족정도값       3.39686   3.28275  3.52982
# clustering        1.00000   2.00000  0.00000

# %%
# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(3)

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(index, total_z[:3]['z_대구부산'], bar_width, alpha=0.4, color='red', label='class1')

b2 = plt.bar(index + bar_width, total_z[:3]['z_광주대전서울'], bar_width, alpha=0.4, color='blue', label='class2')

b3 = plt.bar(index + 2 * bar_width, total_z[:3]['z_울산인천'], bar_width, alpha=0.4, color='green', label='class3')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 3 + bar_width, 1), y_columns)
plt.rc('font', family='NanumBarunGothic') 

# x축, y축 이름 및 범례 설정
plt.xlabel('variable', size = 13)
plt.ylabel('value', size = 13)
plt.rc('font', family='NanumBarunGothic') 
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51068 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47112 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51200 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(8)

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(index, total_z[3:11]['z_대구부산'], bar_width, alpha=0.4, color='red', label='class1')

b2 = plt.bar(index + bar_width, total_z[3:11]['z_광주대전서울'], bar_width, alpha=0.4, color='blue', label='class2')

b3 = plt.bar(index + 2 * bar_width, total_z[3:11]['z_울산인천'], bar_width, alpha=0.4, color='green', label='class3')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 8 + bar_width, 1), y_columns[3:11])
plt.rc('font', family='NanumBarunGothic') 

# x축, y축 이름 및 범례 설정
plt.xlabel('variable', size = 13)
plt.ylabel('value', size = 13)
plt.rc('font', family='NanumBarunGothic') 
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 54868 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 50696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 49696 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
# 그림 사이즈, 바 굵기 조정
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.25

# 연도가 4개이므로 0, 1, 2, 3 위치를 기준으로 삼음
index = np.arange(5)

# 각 연도별로 3개 샵의 bar를 순서대로 나타내는 과정, 각 그래프는 0.25의 간격을 두고 그려짐
b1 = plt.bar(index, total_z[11:16]['z_대구부산'], bar_width, alpha=0.4, color='red', label='class1')

b2 = plt.bar(index + bar_width, total_z[11:16]['z_광주대전서울'], bar_width, alpha=0.4, color='blue', label='class2')

b3 = plt.bar(index + 2 * bar_width, total_z[11:16]['z_울산인천'], bar_width, alpha=0.4, color='green', label='class3')

# x축 위치를 정 가운데로 조정하고 x축의 텍스트를 year 정보와 매칭
plt.xticks(np.arange(bar_width, 5 + bar_width, 1), y_columns[11:16])
plt.rc('font', family='NanumBarunGothic') 

# x축, y축 이름 및 범례 설정
plt.xlabel('variable', size = 13)
plt.ylabel('value', size = 13)
plt.rc('font', family='NanumBarunGothic') 
plt.legend()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 52649 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 48516 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 47564 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51313 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
value_dict = {'변수' : z_columns, 'z_대구부산':z_cluster_3_lst,'z_광주대전서울':z_cluster_2_lst, 'z_울산인천':z_cluster_1_lst }
total_z = pd.DataFrame(value_dict)
total_z
# Out:
#                   변수   z_대구부산  z_광주대전서울   z_울산인천
# 0         평일일평균레저시간값  4.04926   3.53083  3.51842
# 1         주말일평균레저시간값  6.91872   6.86872  6.28684
# 2           1주총레저시간값 34.08374  31.39159 30.16579
# 3     문화예술관람경험_count  0.38793   0.43550  0.57018
# 4   문화예술직접하기경험_count  0.13085   0.10654  0.15263
# 5      스포츠관람경험_count  0.28202   0.26880  0.23860
# 6    스포츠직접하기경험_count  0.46521   0.48832  0.50351
# 7       관광여행경험_count  0.51755   0.54336  0.51667
# 8       자기계발경험_count  0.50985   0.48170  0.60965
# 9       사회교류경험_count  0.45628   0.40934  0.47719
# 10      오락휴식경험_count  0.82451   0.86662  0.78772
# 11         시간충분만족정도값  3.04649   2.98895  3.27632
# 12       인프라및시설만족정도값  3.37069   3.48135  3.22368
# 13         경제여유만족정도값  2.88701   2.70366  2.81404
# 14         정보충분만족정도값  3.44982   3.48392  3.70263
# 15       레저생활전반만족정도값  3.39686   3.28275  3.52982
# 16        clustering  1.00000   2.00000  0.00000

# %%
Total_df = pd.merge(total_y, total_z, on = '변수')
